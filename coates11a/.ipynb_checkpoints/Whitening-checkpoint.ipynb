# %% [markdown]
# ## PCA Whitening
# This script is based on:
# http://ufldl.stanford.edu/tutorial/unsupervised/PCAWhitening/
#
#
# The data is assumed to be a matrix of unrolled images
# the dimensions should be Number of images * Number of pixels per image

# %% [markdown]
# ## Import the needed libraries

# %%
import numpy as np
from six.moves import cPickle
from matplotlib import pyplot as plt
import argparse
# %matplotlib inline

# %% [markdown]
# ## Define the regularization parameter

# %%
epsilon = 10**-5

# %% [markdown]
# ## Read data
# First we read the input data

# %%
input = "../../../cifar.pickle"
with open(input, "rb") as source:
    data = cPickle.load(source)["data"][0:100, 0:2]

# %% [markdown]
# ## We perform normalization of our data

# %%
mean = data.mean(axis=0)
std = data.std(axis=0)
data = (data - mean) / std
plt.scatter(data[:, 0], data[:, 1])
plt.show()

# %% [markdown]
# ## Calculate the covariance matrix of our input

# %%
covariance_matrix = np.cov(data.T)

# %% [markdown]
# ## Compute the Eigen vectors and values of our covariance matrix

# %%
U, S, V = np.linalg.svd(covariance_matrix)

# %% [markdown]
# ## The data rotated

# %%
data_rot = np.dot(data, U)
plt.scatter(data_rot[:, 0], data_rot[:, 1])
plt.show()

# %% [markdown]
# ## PCA Whitening

# %%
data_pca = np.dot(data, np.dot(U, np.diag(1 / np.sqrt(S + epsilon))))
plt.scatter(data_pca[:, 0], data_pca[:, 1])
plt.show()

# %% [markdown]
# ## Perform ZCA whitening

# %%
data_zca = np.dot(data, np.dot(np.dot(U, np.diag(1 / np.sqrt(S + epsilon))), U.T).T)
plt.scatter(data_zca[:, 0], data_zca[:, 1])
plt.show()
